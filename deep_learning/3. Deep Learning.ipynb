# %% [markdown]
# **Deep Learning**
#
# *Dataset: MNIST, CIFAR10*

# %% [markdown]
# **1.	Detect handwritten digit**
#
#
#
# -	Train an MLP/FNN(multilayer perceptron/feedforward neural network) on the MNIST dataset. See if we can get over 98% accuracy.
# -	Try different activation functions
# -   Try different learning rates
# -   Try different architectures

# %%
import tensorflow as tf
from tensorflow import keras
from functools import partial

# Task 1: Detect handwritten digits (MNIST)
# Due to the simplicity of the task, we can use a simple MLP to classify the images with just 1000 first rows only.

def train_mnist_mlp(activation='relu', learning_rate=0.001, hidden_layers=[300, 100]):
    (X_train_full, y_train_full), (X_test, y_test) = keras.datasets.mnist.load_data()
    X_train_full = X_train_full.reshape((60000, 28 * 28)).astype('float32') / 255

    # Limit the training dataset to 1000 rows
    X_train_full = X_train_full[:1000]
    y_train_full = y_train_full[:1000]

    X_test = X_test.reshape((10000, 28 * 28)).astype('float32') / 255
    X_valid, X_train = X_train_full[:500], X_train_full[500:]
    y_valid, y_train = y_train_full[:500], y_train_full[500:]

    model = keras.models.Sequential()
    model.add(keras.layers.Dense(hidden_layers[0], activation=activation, input_shape=X_train.shape[1:]))
    for units in hidden_layers[1:]:
        model.add(keras.layers.Dense(units, activation=activation))
    model.add(keras.layers.Dense(10, activation='softmax'))

    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    history = model.fit(X_train, y_train, epochs=30, validation_data=(X_valid, y_valid))

    test_loss, test_acc = model.evaluate(X_test, y_test)
    print(f"MNIST Test accuracy: {test_acc}")

    return history, test_acc

# Test different configurations
print("MNIST Training with ReLU, lr=0.001:")
train_mnist_mlp()

print("\nMNIST Training with sigmoid, lr=0.01:")
train_mnist_mlp(activation='sigmoid', learning_rate=0.01)

print("\nMNIST Training with hidden layers 500, 200, lr=0.0005:")
train_mnist_mlp(hidden_layers=[500,200], learning_rate=0.0005)
# Out:
# MNIST Training with ReLU, lr=0.001:
# Epoch 1/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3246 - loss: 2.0231 - val_accuracy: 0.7360 - val_loss: 1.1378
# Epoch 2/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8323 - loss: 0.8020 - val_accuracy: 0.8080 - val_loss: 0.6709
# Epoch 3/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8997 - loss: 0.3950 - val_accuracy: 0.8460 - val_loss: 0.5428
# Epoch 4/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9391 - loss: 0.2362 - val_accuracy: 0.8260 - val_loss: 0.5207
# Epoch 5/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9758 - loss: 0.1648 - val_accuracy: 0.8580 - val_loss: 0.4832
# Epoch 6/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9897 - loss: 0.0850 - val_accuracy: 0.8580 - val_loss: 0.5079
# Epoch 7/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0585 - val_accuracy: 0.8660 - val_loss: 0.4631
# Epoch 8/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0370 - val_accuracy: 0.8600 - val_loss: 0.4845
# Epoch 9/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0256 - val_accuracy: 0.8640 - val_loss: 0.4851
# Epoch 10/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0196 - val_accuracy: 0.8660 - val_loss: 0.4936
# Epoch 11/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.8740 - val_loss: 0.4830
# Epoch 12/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 0.8700 - val_loss: 0.4994
# Epoch 13/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.8720 - val_loss: 0.5012
# Epoch 14/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.8700 - val_loss: 0.5076
# Epoch 15/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.8680 - val_loss: 0.5136
# Epoch 16/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.8680 - val_loss: 0.5204
# Epoch 17/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.8720 - val_loss: 0.5203
# Epoch 18/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8700 - val_loss: 0.5267
# Epoch 19/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8680 - val_loss: 0.5281
# Epoch 20/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.8700 - val_loss: 0.5331
# Epoch 21/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8680 - val_loss: 0.5357
# Epoch 22/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8700 - val_loss: 0.5396
# Epoch 23/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8700 - val_loss: 0.5446
# Epoch 24/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.8700 - val_loss: 0.5457
# Epoch 25/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8660 - val_loss: 0.5540
# Epoch 26/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.8680 - val_loss: 0.5552
# Epoch 27/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8680 - val_loss: 0.5584
# Epoch 28/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8680 - val_loss: 0.5620
# Epoch 29/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8660 - val_loss: 0.5648
# Epoch 30/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8660 - val_loss: 0.5679
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - accuracy: 0.8165 - loss: 0.7218
# MNIST Test accuracy: 0.8478999733924866
#
# MNIST Training with sigmoid, lr=0.01:
# Epoch 1/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1237 - loss: 2.5350 - val_accuracy: 0.5140 - val_loss: 1.6436
# Epoch 2/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6839 - loss: 1.3477 - val_accuracy: 0.6920 - val_loss: 0.9208
# Epoch 3/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8072 - loss: 0.6709 - val_accuracy: 0.8320 - val_loss: 0.5764
# Epoch 4/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9285 - loss: 0.3026 - val_accuracy: 0.8280 - val_loss: 0.5485
# Epoch 5/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9736 - loss: 0.1366 - val_accuracy: 0.8440 - val_loss: 0.5489
# Epoch 6/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9870 - loss: 0.0953 - val_accuracy: 0.8300 - val_loss: 0.5835
# Epoch 7/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9933 - loss: 0.0539 - val_accuracy: 0.8540 - val_loss: 0.5261
# Epoch 8/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9982 - loss: 0.0261 - val_accuracy: 0.8620 - val_loss: 0.5298
# Epoch 9/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9930 - loss: 0.0260 - val_accuracy: 0.8660 - val_loss: 0.5297
# Epoch 10/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 0.8620 - val_loss: 0.5386
# Epoch 11/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.8660 - val_loss: 0.5411
# Epoch 12/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.8660 - val_loss: 0.5403
# Epoch 13/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.8640 - val_loss: 0.5540
# Epoch 14/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8660 - val_loss: 0.5557
# Epoch 15/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.8680 - val_loss: 0.5614
# Epoch 16/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.8700 - val_loss: 0.5677
# Epoch 17/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8700 - val_loss: 0.5721
# Epoch 18/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.8700 - val_loss: 0.5762
# Epoch 19/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8700 - val_loss: 0.5810
# Epoch 20/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8680 - val_loss: 0.5855
# Epoch 21/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.8680 - val_loss: 0.5910
# Epoch 22/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8700 - val_loss: 0.5930
# Epoch 23/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8700 - val_loss: 0.5963
# Epoch 24/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8700 - val_loss: 0.6008
# Epoch 25/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8700 - val_loss: 0.6026
# Epoch 26/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8700 - val_loss: 0.6090
# Epoch 27/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8700 - val_loss: 0.6102
# Epoch 28/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8700 - val_loss: 0.6139
# Epoch 29/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8700 - val_loss: 0.6162
# Epoch 30/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8700 - val_loss: 0.6192
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - accuracy: 0.8184 - loss: 0.8123
# MNIST Test accuracy: 0.8460999727249146
#
# MNIST Training with hidden layers 500, 200, lr=0.0005:
# Epoch 1/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4349 - loss: 1.9628 - val_accuracy: 0.7120 - val_loss: 1.2389
# Epoch 2/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8522 - loss: 0.8982 - val_accuracy: 0.7880 - val_loss: 0.7334
# Epoch 3/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9094 - loss: 0.4530 - val_accuracy: 0.8260 - val_loss: 0.5802
# Epoch 4/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9465 - loss: 0.2905 - val_accuracy: 0.8480 - val_loss: 0.4992
# Epoch 5/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9724 - loss: 0.1845 - val_accuracy: 0.8520 - val_loss: 0.5002
# Epoch 6/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9808 - loss: 0.1330 - val_accuracy: 0.8560 - val_loss: 0.4852
# Epoch 7/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9939 - loss: 0.0898 - val_accuracy: 0.8580 - val_loss: 0.4676
# Epoch 8/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9955 - loss: 0.0730 - val_accuracy: 0.8620 - val_loss: 0.4681
# Epoch 9/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9990 - loss: 0.0441 - val_accuracy: 0.8700 - val_loss: 0.4656
# Epoch 10/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0309 - val_accuracy: 0.8580 - val_loss: 0.4804
# Epoch 11/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0266 - val_accuracy: 0.8680 - val_loss: 0.4764
# Epoch 12/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0197 - val_accuracy: 0.8620 - val_loss: 0.4890
# Epoch 13/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0159 - val_accuracy: 0.8720 - val_loss: 0.4845
# Epoch 14/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 0.8660 - val_loss: 0.4916
# Epoch 15/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.8760 - val_loss: 0.4968
# Epoch 16/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.8720 - val_loss: 0.5011
# Epoch 17/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.8680 - val_loss: 0.5048
# Epoch 18/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.8720 - val_loss: 0.5096
# Epoch 19/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.8700 - val_loss: 0.5133
# Epoch 20/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.8720 - val_loss: 0.5192
# Epoch 21/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.8720 - val_loss: 0.5224
# Epoch 22/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8740 - val_loss: 0.5240
# Epoch 23/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.8720 - val_loss: 0.5276
# Epoch 24/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8720 - val_loss: 0.5339
# Epoch 25/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8720 - val_loss: 0.5382
# Epoch 26/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8720 - val_loss: 0.5393
# Epoch 27/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.8700 - val_loss: 0.5426
# Epoch 28/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8700 - val_loss: 0.5447
# Epoch 29/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.8700 - val_loss: 0.5506
# Epoch 30/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.8720 - val_loss: 0.5525
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.8161 - loss: 0.7034
# MNIST Test accuracy: 0.8496999740600586
# (<keras.src.callbacks.history.History at 0x35e64fa00>, 0.8496999740600586)

# %% [markdown]
# **2.	Recognize objects**
#
# -   Train a DNN (deep neural network) with 20 hidden layers and 100 neurons each on the CIFAR10 dataset.
# -   Try ELU activation function
# -   Try NADAM momentum optimization with early stopping
# -   Try Batch Normalization optimization with SELU activation function
# -   Try regularization with dropout
#
# Hints: tensorflow, keras.datasets.mnist.lead_data(), keras.datasets.cifar10.lead_data(), keras.models, heras.layers, keyras.initilizers, keras.optimizers, functools

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

model.summary()
# Out:
# /Users/hungnguy/Library/Python/3.9/lib/python/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 300)            │       235,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 100)            │        30,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 266,610 (1.02 MB)
#  Trainable params: 266,610 (1.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Modify the output layer to produce a tensor with shape (None, 10)
model.add(keras.layers.Flatten())  # Flatten the output before the final Dense layer
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
import tensorflow as tf
from tensorflow import keras

# Load the CIFAR10 dataset
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.cifar10.load_data()

# Limit the training dataset to 1000 rows due to local performance issues
X_train_full = X_train_full[:1000]
y_train_full = y_train_full[:1000]

# Preprocess the data
X_train_full = X_train_full.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0
X_valid, X_train = X_train_full[:500], X_train_full[500:]
y_valid, y_train = y_train_full[:500], y_train_full[500:]

# Define the DNN model with ELU activation and NADAM optimizer
def create_dnn_model(activation='elu', optimizer='nadam', batch_norm=False, dropout_rate=0.0):
    model = keras.models.Sequential()
    model.add(keras.layers.Flatten(input_shape=[32, 32, 3]))
    for _ in range(20):
        if batch_norm:
            model.add(keras.layers.Dense(100, kernel_initializer='lecun_normal', use_bias=False))
            model.add(keras.layers.BatchNormalization())
            model.add(keras.layers.Activation(activation))
        else:
            model.add(keras.layers.Dense(100, activation=activation))
        if dropout_rate > 0:
            model.add(keras.layers.Dropout(dropout_rate))
    model.add(keras.layers.Dense(10, activation='softmax'))

    if optimizer == 'nadam':
        optimizer = keras.optimizers.Nadam()
    else:
        optimizer = keras.optimizers.Adam()

    model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# Train the model with NADAM and early stopping
dnn_model = create_dnn_model()
early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
history_nadam = dnn_model.fit(X_train, y_train, epochs=100, validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])

# Train the model with Batch Normalization and SELU
dnn_model_bn = create_dnn_model(activation='selu', optimizer='adam', batch_norm=True)
history_bn = dnn_model_bn.fit(X_train, y_train, epochs=100, validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])

# Train the model with dropout regularization
dnn_model_dropout = create_dnn_model(dropout_rate=0.2)
history_dropout = dnn_model_dropout.fit(X_train, y_train, epochs=100, validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])

# Evaluate the models
loss_nadam, accuracy_nadam = dnn_model.evaluate(X_test, y_test)
loss_bn, accuracy_bn = dnn_model_bn.evaluate(X_test, y_test)
loss_dropout, accuracy_dropout = dnn_model_dropout.evaluate(X_test, y_test)

print(f'DNN with NADAM - Loss: {loss_nadam}, Accuracy: {accuracy_nadam}')
print(f'DNN with Batch Normalization and SELU - Loss: {loss_bn}, Accuracy: {accuracy_bn}')
print(f'DNN with Dropout - Loss: {loss_dropout}, Accuracy: {accuracy_dropout}')
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.1137 - loss: 2.3835 - val_accuracy: 0.1060 - val_loss: 2.3318
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1212 - loss: 2.3134 - val_accuracy: 0.1640 - val_loss: 2.1921
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1607 - loss: 2.2178 - val_accuracy: 0.1720 - val_loss: 2.1431
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1199 - loss: 2.1534 - val_accuracy: 0.1920 - val_loss: 2.0962
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2645 - loss: 2.0289 - val_accuracy: 0.1920 - val_loss: 2.1288
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2206 - loss: 2.0208 - val_accuracy: 0.2600 - val_loss: 2.0326
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2661 - loss: 1.9676 - val_accuracy: 0.1980 - val_loss: 2.1829
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2604 - loss: 2.0136 - val_accuracy: 0.2160 - val_loss: 2.0618
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2738 - loss: 1.9529 - val_accuracy: 0.2520 - val_loss: 2.0630
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3123 - loss: 1.8527 - val_accuracy: 0.2280 - val_loss: 2.1314
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3471 - loss: 1.8362 - val_accuracy: 0.2180 - val_loss: 2.1439
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3281 - loss: 1.9122 - val_accuracy: 0.2340 - val_loss: 2.1177
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2927 - loss: 1.8347 - val_accuracy: 0.2640 - val_loss: 2.0324
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3434 - loss: 1.7423 - val_accuracy: 0.2560 - val_loss: 2.0916
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3648 - loss: 1.7245 - val_accuracy: 0.2520 - val_loss: 2.2207
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3605 - loss: 1.7124 - val_accuracy: 0.2800 - val_loss: 2.1025
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4203 - loss: 1.5968 - val_accuracy: 0.2680 - val_loss: 2.1419
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4210 - loss: 1.6028 - val_accuracy: 0.2440 - val_loss: 2.3130
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4373 - loss: 1.5533 - val_accuracy: 0.2420 - val_loss: 2.2665
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3797 - loss: 1.6874 - val_accuracy: 0.2620 - val_loss: 2.1939
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5064 - loss: 1.5040 - val_accuracy: 0.2460 - val_loss: 2.2447
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4485 - loss: 1.4991 - val_accuracy: 0.2520 - val_loss: 2.2200
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3978 - loss: 1.5423 - val_accuracy: 0.2620 - val_loss: 2.2069
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.1221 - loss: 2.7746 - val_accuracy: 0.1220 - val_loss: 3.0440
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2178 - loss: 2.1077 - val_accuracy: 0.1140 - val_loss: 2.5671
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3438 - loss: 1.9251 - val_accuracy: 0.1260 - val_loss: 2.7073
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3438 - loss: 1.7614 - val_accuracy: 0.1400 - val_loss: 2.9626
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4201 - loss: 1.6553 - val_accuracy: 0.1800 - val_loss: 2.4674
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3592 - loss: 1.6195 - val_accuracy: 0.1820 - val_loss: 2.6331
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4601 - loss: 1.4771 - val_accuracy: 0.1680 - val_loss: 3.3545
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5089 - loss: 1.4136 - val_accuracy: 0.2000 - val_loss: 2.7290
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5353 - loss: 1.2704 - val_accuracy: 0.1820 - val_loss: 3.2559
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5712 - loss: 1.2911 - val_accuracy: 0.2500 - val_loss: 2.8561
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5848 - loss: 1.1289 - val_accuracy: 0.1920 - val_loss: 3.0754
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6143 - loss: 1.0328 - val_accuracy: 0.2060 - val_loss: 3.1628
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5669 - loss: 1.0920 - val_accuracy: 0.2540 - val_loss: 3.2592
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6638 - loss: 0.9680 - val_accuracy: 0.1720 - val_loss: 3.8846
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6787 - loss: 0.9673 - val_accuracy: 0.2240 - val_loss: 3.4314
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.1058 - loss: 2.4303 - val_accuracy: 0.1000 - val_loss: 2.3199
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1141 - loss: 2.4315 - val_accuracy: 0.0840 - val_loss: 2.3100
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1007 - loss: 2.3867 - val_accuracy: 0.1420 - val_loss: 2.3124
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1245 - loss: 2.3336 - val_accuracy: 0.0860 - val_loss: 2.3271
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1220 - loss: 2.3699 - val_accuracy: 0.1300 - val_loss: 2.3116
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1287 - loss: 2.3846 - val_accuracy: 0.0980 - val_loss: 2.3012
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1227 - loss: 2.3917 - val_accuracy: 0.0860 - val_loss: 2.3242
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0978 - loss: 2.3940 - val_accuracy: 0.1000 - val_loss: 2.3154
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1110 - loss: 2.4006 - val_accuracy: 0.0900 - val_loss: 2.3157
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1001 - loss: 2.3637 - val_accuracy: 0.1320 - val_loss: 2.3132
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1095 - loss: 2.3766 - val_accuracy: 0.0980 - val_loss: 2.3059
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0694 - loss: 2.3949 - val_accuracy: 0.1300 - val_loss: 2.2976
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1155 - loss: 2.3409 - val_accuracy: 0.1000 - val_loss: 2.3031
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1092 - loss: 2.3681 - val_accuracy: 0.0900 - val_loss: 2.3133
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1065 - loss: 2.3386 - val_accuracy: 0.0840 - val_loss: 2.3141
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0871 - loss: 2.3620 - val_accuracy: 0.0800 - val_loss: 2.3226
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0852 - loss: 2.3595 - val_accuracy: 0.1180 - val_loss: 2.3188
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1155 - loss: 2.3426 - val_accuracy: 0.1060 - val_loss: 2.3172
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1137 - loss: 2.3372 - val_accuracy: 0.1000 - val_loss: 2.3098
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1007 - loss: 2.3350 - val_accuracy: 0.0860 - val_loss: 2.3201
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0914 - loss: 2.3441 - val_accuracy: 0.1120 - val_loss: 2.3142
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0816 - loss: 2.3548 - val_accuracy: 0.1380 - val_loss: 2.3179
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2629 - loss: 2.0732
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1837 - loss: 2.4981
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0966 - loss: 2.3119
# DNN with NADAM - Loss: 2.0773050785064697, Accuracy: 0.2630000114440918
# DNN with Batch Normalization and SELU - Loss: 2.485943078994751, Accuracy: 0.18799999356269836
# DNN with Dropout - Loss: 2.3118717670440674, Accuracy: 0.10029999911785126
